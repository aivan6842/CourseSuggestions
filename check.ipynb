# %%
from elasticsearch import Elasticsearch, helpers
import json

# %%
from indexing.enums.index_names import IndexName
from indexing.mappings.mappings import ESMappings

# %%
# Password for the 'elastic' user generated by Elasticsearch
from shared.configs.elastic_search_config import ELASTIC_PASSWORD

# Create the client instance
es = Elasticsearch(
    "https://localhost:9200",
    ca_certs="config/certs/http_ca.crt",
    basic_auth=("elastic", ELASTIC_PASSWORD),
    verify_certs=False
)
# Out:
# d:\Python 3.10.9\lib\site-packages\elasticsearch\_sync\client\__init__.py:394: SecurityWarning: Connecting to 'https://localhost:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(

# %%
# create index
index_name = IndexName.UWATERLOO_COURSES_INDEX.value
mapping = ESMappings.get_mapping_from_index_name(index_name)

# %%
es.search(index=IndexName.UWATERLOO_COURSES_INDEX.value, body={"from": 0, "size": 5, "query": {"match": {"courseDescription": "Mathematical Statistics"}}})
# Out:
# C:\Users\nicki\AppData\Local\Temp\ipykernel_23384\2540895700.py:1: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   es.search(index=IndexName.UWATERLOO_COURSES_INDEX.value, body={"from": 0, "size": 5, "query": {"match": {"courseDescription": "Mathematical Statistics"}}})
# d:\Python 3.10.9\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
from evaluation.metrics.mapk import Mapk

y = ['STAT330', 'STAT331', 'STAT322', 'STAT333', 'STAT334']
yhat = ['STAT330', 'STAT331', 'STAT322', 'STAT333', 'STAT334']
k=5
m = Mapk()
print(m.evaluate(y=y, yhat=yhat))
# Out:
# ['STAT330', 'MAT245', 'GEOG 341', 'MAT245', 'STAT322']
# 0.27999999999999997
